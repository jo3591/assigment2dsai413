# %% [markdown]
# # 05 — QA Mode Evaluation
#
# Runs all 5 configs on `data/qa/qa_test.jsonl` and writes `results/tables/qa_metrics.csv`. Also runs retrieval evaluation across all 3 backends.

# %%
# !python scripts/run_eval.py --mode qa --configs all --test-size 200 --top-k 3

# %%
# !python scripts/run_eval.py --mode retrieval --test-size 200

# %%
import pandas as pd
print('QA metrics:')
print(pd.read_csv('results/tables/qa_metrics.csv'))
print('\nRetrieval metrics:')
print(pd.read_csv('results/tables/retrieval_metrics.csv'))
