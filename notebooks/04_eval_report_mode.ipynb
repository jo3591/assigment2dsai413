# %% [markdown]
# # 04 — Report Mode Evaluation
#
# Runs all 5 configs (MedGemma-only, BiomedCLIP-RAG, ColPali-zs-RAG, ColPali-LoRA-RAG, text-only LLM) on the test set and writes `results/tables/report_metrics.csv`.

# %%
# !python scripts/build_indices.py --backend biomedclip --backend colpali_zs --backend colpali_lora

# %%
# !python scripts/run_eval.py --mode report --configs all --test-size 200 --top-k 3

# %%
import pandas as pd
pd.read_csv('results/tables/report_metrics.csv')
