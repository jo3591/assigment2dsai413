# %% [markdown]
# # 01 — Data Exploration
#
# Goal: download the Kaggle MIMIC-CXR subset, preprocess reports, compute CheXpert labels, build splits, and inspect distributions.
#
# **Run on Colab.** Mount Drive first; this notebook expects the repo cloned at `/content/cxr-intel`.

# %%
# Colab bootstrap (skip if running locally)
import os, sys
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/cxr-intel
    # !bash scripts/colab_bootstrap.sh

# %%
# !python scripts/download_data.py --config configs/data.yaml

# %%
import pandas as pd
df = pd.read_parquet('data/processed/reports.parquet')
print(df.shape)
df.head()

# %%
df['primary_chexpert_label'].value_counts().plot(kind='barh')

# %%
import json
splits = json.load(open('data/processed/splits.json'))
{k: len(v) for k, v in splits.items()}
